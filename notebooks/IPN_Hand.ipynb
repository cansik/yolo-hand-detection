# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os

vidpath = '/born-again/datasets/IPN_Hand/videos/1CM1_1_R_#217.avi'
segfolder = '/born-again/datasets/IPN_Hand/segment/1CM1_1_R_#217'

# %%
cap = cv2.VideoCapture(vidpath)

# %%
for i in range(100):
    ok, frame = cap.read()
frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(frame)

# %%
files = os.listdir(segfolder)
numf = len(files)
paths = [os.path.join(segfolder, file) for file in files]
length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
length, numf
# Out:
# (3987, 3854)

# %%
length/numf
# Out:
# 1.034509600415153

# %%
off = length-numf

# %%
index = round(99*numf/length)
# index = 99+off-4
# index = np.random.choice(numf)

# %%
seg = cv2.imread(paths[index])

seg = cv2.resize(seg, (640,480))

# %%
plt.imshow(seg)

# %%
test = (frame*0.5 + seg*0.5).astype(np.uint8)

# %%
plt.imshow(test)

# %%
import sys
sys.path.append('../../mediapipe')

from mediapipe.python.solutions.hands import Hands
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_32980/1179225030.py in <module>
#       2 sys.path.append('../../mediapipe')
#       3
# ----> 4 from mediapipe.python.solutions.hands import Hands
#
# ~/Homework/csci4831/mediapipe/mediapipe/python/__init__.py in <module>
#      15 """MediaPipe Python API."""
#      16
# ---> 17 from mediapipe.python._framework_bindings import resource_util
#      18 from mediapipe.python._framework_bindings.calculator_graph import CalculatorGraph
#      19 from mediapipe.python._framework_bindings.calculator_graph import GraphInputStreamAddMode
#
# ModuleNotFoundError: No module named 'mediapipe.python._framework_bindings'
